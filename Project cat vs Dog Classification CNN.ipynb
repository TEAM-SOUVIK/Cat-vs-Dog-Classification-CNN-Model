# %%
# !mkdir C:\Users\Public\.kaggle
# !copy kaggle.json C:\Users\Public\.kaggle\
# Out:
# A subdirectory or file C:\Users\Public\.kaggle already exists.
#         1 file(s) copied.

# %%
# !kaggle datasets download -d salader/dogs-vs-cats --force
# Out:
# ...
#   0%|          | 0.00/1.06G [00:00<?, ?B/s]
#   0%|          | 1.00M/1.06G [00:00<14:33, 1.31MB/s]
#   0%|          | 3.00M/1.06G [00:01<05:20, 3.56MB/s]
#   0%|          | 4.00M/1.06G [00:01<04:24, 4.30MB/s]
#   1%|          | 6.00M/1.06G [00:01<02:55, 6.47MB/s]
#   1%|          | 7.00M/1.06G [00:01<02:44, 6.90MB/s]
#   1%|          | 8.00M/1.06G [00:01<02:35, 7.31MB/s]
#   1%|          | 9.00M/1.06G [00:01<02:45, 6.86MB/s]
#   1%|          | 10.0M/1.06G [00:01<02:31, 7.48MB/s]
#   1%|1         | 12.0M/1.06G [00:02<02:17, 8.24MB/s]
#   1%|1         | 13.0M/1.06G [00:02<02:27, 7.68MB/s]
#   1%|1         | 14.0M/1.06G [00:02<02:27, 7.64MB/s]
#   1%|1         | 15.0M/1.06G [00:02<02:18, 8.16MB/s]
#   1%|1         | 16.0M/1.06G [00:02<02:24, 7.77MB/s]
#   2%|1         | 18.0M/1.06G [00:02<02:08, 8.72MB/s]
#   2%|1         | 19.0M/1.06G [00:03<02:24, 7.75MB/s]
#   2%|1         | 21.0M/1.06G [00:03<02:22, 7.84MB/s]
#   2%|2         | 23.0M/1.06G [00:03<02:15, 8.29MB/s]
# ...

# %%
import zipfile
zip_ref = zipfile.ZipFile('E:\jupyter Notebook Files\dogs-vs-cats.zip', 'r')
zip_ref.extractall('E:\jupyter Notebook Files')
zip_ref.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequentialfrom keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
# Out:
#   Cell In[22], line 3
#     from keras import Sequentialfrom keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
#                                      ^
# SyntaxError: invalid syntax

# %%
# generators
train_ds = keras.utils.image_dataset_from_directory(
    directory = 'E:\jupyter Notebook Files/train',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(256,256)
)

validation_ds = keras.utils.image_dataset_from_directory(
    directory = 'E:\jupyter Notebook Files/test',
    labels='inferred',
    label_mode = 'int',
    
    batch_size=32,
    image_size=(256,256)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # generators
# ----> 2 train_ds = keras.utils.image_dataset_from_directory(
#       3     directory = 'E:\jupyter Notebook Files/train',
#       4     labels='inferred',
#       5     label_mode = 'int',
#       6     batch_size=32,
#       7     image_size=(256,256)
#       8 )
#      10 validation_ds = keras.utils.image_dataset_from_directory(
#      11     directory = 'E:\jupyter Notebook Files/test',
#      12     labels='inferred',
#    (...)
#      16     image_size=(256,256)
#      17 )
#
# NameError: name 'keras' is not defined

# %%
# Normalize
def process(image,label):
    image = tf.cast(image/255. ,tf.float32)
    return image,label

train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
# create CNN model

model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(128,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1,activation='sigmoid'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # create CNN model
# ----> 3 model = Sequential()
#       5 model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3)))
#       6 model.add(BatchNormalization())
#
# NameError: name 'Sequential' is not defined

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  batch_normalization (Batch  (None, 254, 254, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 125, 125, 64)      256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 60, 60, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 115200)            0
#
#  dense (Dense)               (None, 128)               14745728
#
#  dropout (Dropout)           (None, 128)               0
#
# ...

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train_ds,epochs=10,validation_data=validation_ds)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 1437s 2s/step - loss: 1.3416 - accuracy: 0.5767 - val_loss: 0.6216 - val_accuracy: 0.6746
# Epoch 2/10
# 625/625 [==============================] - 1379s 2s/step - loss: 0.5947 - accuracy: 0.6850 - val_loss: 0.7101 - val_accuracy: 0.5930
# Epoch 3/10
# 625/625 [==============================] - 1214s 2s/step - loss: 0.5134 - accuracy: 0.7489 - val_loss: 0.6432 - val_accuracy: 0.6654
# Epoch 4/10
# 625/625 [==============================] - 1195s 2s/step - loss: 0.4448 - accuracy: 0.7952 - val_loss: 0.4439 - val_accuracy: 0.7948
# Epoch 5/10
# 625/625 [==============================] - 1192s 2s/step - loss: 0.3761 - accuracy: 0.8330 - val_loss: 0.8380 - val_accuracy: 0.6558
# Epoch 6/10
# 625/625 [==============================] - 1195s 2s/step - loss: 0.3089 - accuracy: 0.8668 - val_loss: 0.7891 - val_accuracy: 0.6728
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.plot(history.history['accuracy'],color='red',label='train')
#       4 plt.plot(history.history['val_accuracy'],color='blue',label='validation')
#       5 plt.legend()
#
# NameError: name 'history' is not defined

# %%
plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.plot(history.history['accuracy'],color='red',label='train')
#       2 plt.plot(history.history['val_accuracy'],color='blue',label='validation')
#       3 plt.legend()
#
# NameError: name 'plt' is not defined

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
# ways to reduce overfitting

# Add more data
# Data Augmentation -> next video
# L1/L2 Regularizer
# Dropout
# Batch Norm
# Reduce complexity

# %%
import cv2

# %%
test_img = cv2.imread('/content/cat.jpg')

# %%
plt.imshow(test_img)

# %%
test_img.shape

# %%
test_img = cv2.resize(test_img,(256,256))

# %%
test_input = test_img.reshape((1,256,256,3))

# %%
model.predict(test_input)
